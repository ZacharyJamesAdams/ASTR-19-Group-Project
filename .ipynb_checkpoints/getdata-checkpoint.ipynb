# %%
import time
DEFAULT_PATH = 'ASTR19_F25_group_project_data.txt'

# %%
def get_data(filename = DEFAULT_PATH):
    data_dict = dict()
    with open(filename,'r') as file:
        lines = file.readlines()
    for i,l in enumerate(lines):
        items = l.split()
        print(f'{i:02}: {repr(items)}')
        if items[0].lower() == '#column':
            label = ''.join([c for c in items[1] if c.isalnum()])
            description = ' '.join(items[2:])
            print(f'  {label = }  {description = }')

# %%
def main():
    get_data()

# %%
if __name__ == "__main__":
    main()
# Out:
# 00: ['#Column', 'A:', 'Day', 'of', 'the', 'year']
#   label = 'A'  description = 'Day of the year'
# 01: ['#Column', 'B:', 'Time', 'in', 'hours:minutes']
#   label = 'B'  description = 'Time in hours:minutes'
# 02: ['#Column', 'C:', 'Tide', 'Height', 'in', 'feet']
#   label = 'C'  description = 'Tide Height in feet'
# 03: ['1', '8:07', '6.57']
# 04: ['1', '15:37', '-0.39']
# 05: ['2', '8:55', '5.38']
# 06: ['2', '16:25', '-1.74']
# 07: ['3', '9:45', '5.26']
# 08: ['3', '17:14', '-1.36']
# 09: ['4', '10:35', '4.13']
# 10: ['4', '18:00', '-1.15']
# 11: ['5', '11:28', '3.48']
# 12: ['5', '18:46', '-1.61']
# 13: ['6', '12:22', '2.62']
# 14: ['6', '19:31', '0.05']
# 15: ['7', '13:24', '1.83']
# 16: ['7', '20:16', '1.01']
# 17: ['8', '3:22', '3.57']
# 18: ['8', '21:01', '0.73']
# 19: ['9', '4:07', '4.54']
# 20: ['9', '21:46', '2.17']
# 21: ['10', '4:50', '3.76']
# 22: ['10', '11:58', '2.88']
# 23: ['11', '5:31', '3.90']
# 24: ['11', '12:56', '1.92']
# 25: ['12', '6:08', '4.73']
# 26: ['12', '13:45', '1.74']
# 27: ['13', '6:47', '5.66']
# 28: ['13', '14:25', '0.79']
# 29: ['14', '7:22', '5.33']
# 30: ['14', '15:00', '-0.04']
# 31: ['15', '7:59', '5.23']
# 32: ['15', '15:34', '-1.12']
# 33: ['16', '8:34', '6.67']
# 34: ['16', '16:08', '-0.61']
# 35: ['17', '9:10', '4.74']
# 36: ['17', '16:41', '-0.93']
# 37: ['18', '9:45', '4.69']
# 38: ['18', '17:12', '-1.29']
# 39: ['19', '10:21', '4.20']
# 40: ['19', '17:45', '0.22']
# 41: ['20', '10:57', '3.68']
# 42: ['20', '18:15', '0.26']
# 43: ['21', '11:38', '2.47']
# 44: ['21', '18:48', '0.36']
# 45: ['22', '12:25', '2.59']
# 46: ['22', '19:20', '0.99']
# 47: ['23', '2:22', '4.10']
# 48: ['23', '19:52', '1.87']
# 49: ['24', '2:58', '3.17']
# 50: ['24', '20:30', '1.60']
# 51: ['25', '3:37', '3.71']
# 52: ['25', '10:44', '3.10']
# 53: ['26', '4:23', '4.04']
# 54: ['26', '11:55', '2.49']
# 55: ['27', '5:15', '4.07']
# 56: ['27', '12:57', '2.18']
# 57: ['28', '6:09', '5.93']
# 58: ['28', '13:50', '0.70']
# 59: ['29', '7:05', '6.89']
# 60: ['29', '14:39', '0.21']
# 61: ['30', '7:58', '6.72']
# 62: ['30', '15:27', '0.22']
# 63: ['31', '8:50', '6.77']
# 64: ['31', '16:10', '-1.68']
# 65: ['32', '9:40', '5.77']
# 66: ['32', '16:52', '-1.32']
# 67: ['33', '10:30', '4.35']
# 68: ['33', '17:34', '-0.73']
# 69: ['34', '11:19', '4.23']
# 70: ['34', '18:12', '-0.38']
# 71: ['35', '12:10', '2.24']
# 72: ['35', '18:49', '-0.61']
# 73: ['36', '1:32', '3.45']
# 74: ['36', '19:24', '-0.46']
# 75: ['37', '2:13', '4.13']
# 76: ['37', '20:00', '1.21']
# 77: ['38', '2:54', '3.34']
# 78: ['38', '9:54', '2.58']
# 79: ['39', '3:39', '3.32']
# 80: ['39', '11:15', '3.26']
# 81: ['40', '4:29', '5.21']
# 82: ['40', '12:22', '2.39']
# 83: ['41', '5:21', '4.83']
# 84: ['41', '13:14', '2.41']
